# %%
import pandas as pd

# %%
info = {

    "Name" : ["Shubh","Riddhi","Shradha","Deepak"] ,
    "CGPA" : [9.5 , 8.4 , 7.7 , 6.6]
}

df = pd.DataFrame(info)
print(df)
# Out:
#       Name  CGPA
# 0    Shubh   9.5
# 1   Riddhi   8.4
# 2  Shradha   7.7
# 3   Deepak   6.6

# %%
df
# Out:
#       Name  CGPA
# 0    Shubh   9.5
# 1   Riddhi   8.4
# 2  Shradha   7.7
# 3   Deepak   6.6
