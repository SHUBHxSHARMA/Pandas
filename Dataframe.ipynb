# %%
import pandas as pd
# DATA FRAME

info = {
    "Name" : ["Adam" , "Eve" , "Bob"],
    "Age" : [23 ,24 ,25] ,
    "CGPA" : [5.9 , 8.6 , 7.5]
 }
df = pd.DataFrame(info)
print(df)
# Out:
#    Name  Age  CGPA
# 0  Adam   23   5.9
# 1   Eve   24   8.6
# 2   Bob   25   7.5

# %%
df
# Out:
#    Name  Age  CGPA
# 0  Adam   23   5.9
# 1   Eve   24   8.6
# 2   Bob   25   7.5

# %%
# tp print the row we have a property called df.index
print(df.index)
# and if we want to get the column values then we use df .column
print(df.columns)
# Out:
# RangeIndex(start=0, stop=3, step=1)
# Index(['Name', 'Age', 'CGPA'], dtype='str')

# %%
df = pd.DataFrame([["ADAM",23],["BOB",24],["CHRIS",24]] ,columns = ["Name","Age"])
print(df)
# Out:
#     Name  Age
# 0   ADAM   23
# 1    BOB   24
# 2  CHRIS   24

# %%
import numpy as np

np_arr = np.array([[1,2,3] , [4,5,6]])
df = pd.DataFrame(np_arr , columns = ["A","B","C"])
print(df)
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
