# %%
import numpy as np
import time

# %%
size = 10_000_0000
py_list = list(range(size))
start = time.time()
sqare_list = [x**2 for x in py_list]
end = time.time()
print(f"The time taken by python list is {end-start}")

num_arr = np.array(py_list)
start = time.time()
sq_array = num_arr ** 2
end = time.time()
print(f"The time taken by numpy array list is {end-start}")
# Out:
# The time taken by python list is 11.33317255973816
# The time taken by numpy array list is 0.22101712226867676

# %% [markdown]
# #memory
# import sys
#
# print(f"python list size = {sys.getsizeof(py_list) * len(py_list)}")
#
# print(f"numpy arrray size = {num_arr.nbytes} bytes")
